# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/src
# Out:
# /content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/src

# %%
# !pip install hydra-core==0.11.3
# Out:
# Requirement already satisfied: hydra-core==0.11.3 in /usr/local/lib/python3.10/dist-packages (0.11.3)
# Requirement already satisfied: omegaconf<1.5,>=1.4 in /usr/local/lib/python3.10/dist-packages (from hydra-core==0.11.3) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from omegaconf<1.5,>=1.4->hydra-core==0.11.3) (1.16.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from omegaconf<1.5,>=1.4->hydra-core==0.11.3) (6.0.1)

# %%
# !pip install pyclipper
# Out:
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (1.3.0.post5)

# %%
# !python train.py
# Out:
# 2024-06-26 15:47:16.168216: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 15:47:16.168302: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 15:47:16.179042: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-26 15:47:16.194005: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-26 15:47:19.516962: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2024-06-26 15:47:28,555][/content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/train.log][INFO] - /content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/logs/1719416848
# [2024-06-26 15:47:28,569][/content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/train.log][INFO] - cpu
# load from imagenet
# [2024-06-26 15:47:28,964][/content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/train.log][INFO] - Loading best checkpoint: /content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/weights/best_pretrained_dbnet.pth
# [2024-06-26 15:47:30,933][/content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/train.log][INFO] - Learning rate scheduler: poly
# [2024-06-26 15:47:30,934][/content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/train.log][INFO] - Dataset name: mix
# [2024-06-26 15:47:30,934][/content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/train.log][INFO] - Ignore tags: ['***']
# True True
# 2401
# [2024-06-26 15:49:15,576][/content/gdrive/MyDrive/Teaching/codes/ocr_27062024/text_detection/src/DB_text_minimal/train.log][INFO] - Start training!
# Epoch 1/50
#   6% 19/300 [08:51<2:11:06, 27.99s/it]^C
